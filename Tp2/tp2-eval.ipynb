# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linspsace

N=[1,1,20]
D=0.3324
Dmax=0.32832
z=45
X= lambda N: N/((N*D)+Z)
y=  lambda N: N/(D+z)
Z= 1/Dmax
d= lambda N: N
T=linspace(0,20,50)
plt.title("courbe1")
plt.plot(T,y(T),"r",T,d(T),'g',T,X(T),'b')
plt.show()
